# %% [markdown]
# <a href="https://colab.research.google.com/github/EagleFury2607/MyCNN/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python download_images.py --urls urls.txt --output data/idli
# Out:
# [INFO] downloaded: data/idli/00000000.jpg
# [INFO] downloaded: data/idli/00000001.jpg
# [INFO] downloaded: data/idli/00000002.jpg
# [INFO] downloaded: data/idli/00000003.jpg
# [INFO] downloaded: data/idli/00000004.jpg
# [INFO] downloaded: data/idli/00000005.jpg
# [INFO] downloaded: data/idli/00000006.jpg
# [INFO] downloaded: data/idli/00000007.jpg
# [INFO] downloaded: data/idli/00000008.jpg
# [INFO] downloaded: data/idli/00000009.jpg
# [INFO] downloaded: data/idli/00000010.jpg
# [INFO] downloaded: data/idli/00000011.jpg
# [INFO] downloaded: data/idli/00000012.jpg
# [INFO] downloaded: data/idli/00000013.jpg
# [INFO] downloaded: data/idli/00000014.jpg
# [INFO] downloaded: data/idli/00000015.jpg
# [INFO] downloaded: data/idli/00000016.jpg
# [INFO] downloaded: data/idli/00000017.jpg
# [INFO] downloaded: data/idli/00000018.jpg
# [INFO] downloaded: data/idli/00000019.jpg
# [INFO] downloaded: data/idli/00000020.jpg
# [INFO] downloaded: data/idli/00000021.jpg
# ...

# %%
# !python prepareData.py
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile

# %%
# !python myModel.py
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0804 14:37:04.074866 140469734832000 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 515 samples, validate on 58 samples
# 2019-08-04 14:37:04.548752: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-08-04 14:37:04.548957: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2a552c0 executing computations on platform Host. Devices:
# 2019-08-04 14:37:04.548984: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# ...

# %%
# !python runScript.py --image idli1.jpeg
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0804 14:37:20.461740 140113873516416 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0804 14:37:20.462062 140113873516416 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...
